# %% [markdown]
# # Очистка БД tiny от не нужных данных

# %%
from source.tinydb_manager import TinyDB_manager
from source.llm_manager import LMStudioClient
from typing import Dict, Any, List
from tqdm import tqdm

# %%
LLM_config_path = "config/LLM/qwen3-1.7b.yaml"

# %%
LLM_config = LMStudioClient.load_config(LLM_config_path)

LLM_NAME = LLM_config['model_name']

result_path = f"benchmark/output_LLM/{LLM_NAME}.json".replace('-', '_')

tiny_manager = TinyDB_manager(result_path)

# %%
all_ids = tiny_manager.get_all_ids()
len(all_ids)
# Out:
# 200

# %%
for ids in all_ids[-30:]:
    print(tiny_manager.delete_id(ids))
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %%
all_ids
# Out:
# ['0105522v1',
#  '2309.00201v2',
#  '2409.08175v1',
#  '2002.04991v1',
#  '2402.06452v1',
#  '0504056v1',
#  '2010.14616v1',
#  '1505.02965v2',
#  '2405.03720v1',
#  '2402.04453v1',
#  '1104.4174v1',
#  '2108.10078v1',
#  '2306.13586v1',
#  '2303.02715v1',
#  '2111.08438v1',
#  '2501.12927v1',
#  '2102.02850v3',
#  '2012.02526v2',
#  '2110.01856v1',
#  '2009.07708v1',
#  '1511.05520v1',
#  '2005.11394v1',
#  '2106.08671v2',
#  '1805.04825v1',
#  '2502.07081v2',
#  '2501.16247v1',
#  '2302.02016v1',
#  '1211.1127v1',
#  '2501.06863v1',
#  '1804.03313v1',
#  '2004.02401v1',
#  '2210.00770v1',
#  '2305.11304v2',
#  '2211.00176v1',
#  '2305.10344v2',
#  '2007.04446v1',
#  '2008.09306v1',
#  '2211.15869v1',
#  '2006.02158v2',
#  '1702.06794v1',
#  '2209.15308v1',
#  '1911.05640v2',
#  '2206.06828v1',
#  '2010.06026v1',
#  '2007.04911v2',
#  '2208.10651v1',
#  '1205.1938v1',
#  '2307.12343v1',
#  '2405.09305v1',
#  '2401.17200v1',
#  '2312.06833v2',
#  '2412.06481v1',
#  '2108.11053v1',
#  '2405.06323v1',
#  '2005.13449v1',
#  '2206.03950v3',
#  '2311.10905v1',
#  '1706.01109v2',
#  '1808.05443v1',
#  '1507.06923v1',
#  '2203.14474v1',
#  '1307.6275v1',
#  '0910.4472v2',
#  '2209.05559v6',
#  '1811.07311v2',
#  '2304.02781v1',
#  '2212.08930v4',
#  '1312.7118v1',
#  '1402.5724v1',
#  '2103.15593v1',
#  '1805.00980v1',
#  '1112.6281v1',
#  '1806.01756v1',
#  '2012.08044v2',
#  '2211.08282v1',
#  '2202.01214v1',
#  '1701.00867v1',
#  '2501.14940v3',
#  '1301.3583v4',
#  '1303.2104v1',
#  '0909.2332v1',
#  '1711.01739v1',
#  '1808.10009v1',
#  '2308.14478v1',
#  '2110.04942v1',
#  '1510.05684v2',
#  '2306.08001v1',
#  '2010.05522v1',
#  '2010.08034v1',
#  '2401.06793v1',
#  '1506.01055v1',
#  '1612.07993v1',
#  '2106.12798v2',
#  '2305.03360v1',
#  '1212.0238v1',
#  '0010231v1',
#  '1104.4188v1',
#  '2108.01468v1',
#  '2101.06480v1',
#  '2106.03259v1',
#  '2006.11014v1',
#  '2305.06063v2',
#  '2410.12598v2',
#  '2204.00778v1',
#  '1607.07625v1',
#  '2003.09873v1',
#  '2304.12729v2',
#  '1811.07579v2',
#  '1408.3002v1',
#  '1803.07418v1',
#  '1412.2352v1',
#  '2401.00974v1',
#  '1904.10551v1',
#  '2406.16106v1',
#  '1702.07956v5',
#  '1805.00559v1',
#  '2004.07136v1',
#  '2007.06559v2',
#  '1805.02716v1',
#  '2006.13307v1',
#  '0012536v1',
#  '1302.4207v1',
#  '1910.12249v1',
#  '1502.06254v2',
#  '1710.06798v1',
#  '2308.02870v1',
#  '2005.03476v2',
#  '2002.07971v2',
#  '2210.08288v1',
#  '2107.02331v1',
#  '1910.12207v1',
#  '1807.04739v1',
#  '2003.08445v1',
#  '1902.01544v1',
#  '2106.13743v1',
#  '1810.11363v1',
#  '1805.11474v3',
#  '2104.04375v1',
#  '2409.18583v1',
#  '2410.20161v1',
#  '1705.04153v1',
#  '2406.03348v1',
#  '1908.06951v1',
#  '1609.01228v1',
#  '2111.15258v1',
#  '2411.01881v2',
#  '1503.03168v1',
#  '2309.00626v1',
#  '1711.11008v1',
#  '2304.02260v1',
#  '1812.02897v3',
#  '2012.03575v1',
#  '2204.12244v1',
#  '2502.08869v1',
#  '1806.08874v1',
#  '2005.09148v1',
#  '2308.08682v1',
#  '1703.02910v1',
#  '2204.09021v1',
#  '1902.07068v1',
#  '2006.10562v4',
#  '2008.01171v1',
#  '1706.09796v3',
#  '2001.09608v1',
#  '2007.05035v1',
#  '1104.4193v1',
#  '0804.0099v1',
#  '2408.09908v2',
#  '1705.03921v1',
#  '0501077v1',
#  '1808.08111v1',
#  '2308.11924v1',
#  '1704.00405v2',
#  '2006.04059v1',
#  '2410.18950v1',
#  '2007.02259v1',
#  '1105.0522v1',
#  '1902.06127v2',
#  '1908.11215v1',
#  '2005.00524v1',
#  '1809.06995v1',
#  '2309.06659v2',
#  '2104.13386v1',
#  '2304.13812v1',
#  '2109.13233v1',
#  '1706.07525v1',
#  '2501.16374v2',
#  '2305.10114v1',
#  '1704.01664v1',
#  '1710.08952v1',
#  '1603.03719v1',
#  '2210.11024v1',
#  '2207.02763v1',
#  '2101.05840v1',
#  '2408.15452v1',
#  '2302.02756v1',
#  '2208.11873v1',
#  '1709.05067v1',
#  '2009.01564v2',
#  '2209.03032v1']
